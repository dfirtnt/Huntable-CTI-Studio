# %% [markdown]
# # LMStudio Model Comparison Tool
#
# Test user-provided text blocks across multiple LMStudio models.
#
# ## Models to Test:
# 1. Mistral 7B Instruct v0.3
# 2. Meta-Llama-3-8B-Instruct
# 3. Nous Hermes 2 Mistral 7B
# 4. GPT-OSS 20B
# 5. Qwen2 7B Instruct
# 6. Phi-3 Mini 3.8B Instruct

# %%
import asyncio
import httpx
import json
import os
import time
from datetime import datetime
from typing import Dict, List, Optional, Tuple
from IPython.display import display, HTML, Markdown
import pandas as pd

# Configuration
LMSTUDIO_BASE_URL = os.getenv("LMSTUDIO_API_URL", "http://localhost:1234/v1")
if "/v1" not in LMSTUDIO_BASE_URL:
    LMSTUDIO_BASE_URL = f"{LMSTUDIO_BASE_URL.rstrip('/')}/v1"

# Models to test (exact names as they appear in LMStudio)
# Update these to match your actual model names
MODELS = [
    "mistral-7b-instruct-v0.3",
    "Meta-Llama-3-8B-Instruct",
    "Nous-Hermes-2-Mistral-7B",
    "GPT-OSS-20B",
    "Qwen2-7B-Instruct",
    "Phi-3-mini-3.8B-Instruct"
]

print(f"LMStudio URL: {LMSTUDIO_BASE_URL}")
print(f"Models to test: {len(MODELS)}")
# Out:
# LMStudio URL: http://localhost:1234/v1
# Models to test: 6

# %% [markdown]
# ## Step 1: Check Available Models
#
# Verify which models are currently loaded in LMStudio.

# %%
async def get_available_models() -> List[str]:
    """Fetch list of available models from LMStudio."""
    try:
        async with httpx.AsyncClient() as client:
            response = await client.get(
                f"{LMSTUDIO_BASE_URL}/models",
                timeout=10.0
            )
            if response.status_code == 200:
                data = response.json()
                models = [model["id"] for model in data.get("data", [])]
                return models
            else:
                print(f"❌ Failed to fetch models: {response.status_code}")
                return []
    except Exception as e:
        print(f"❌ Error fetching models: {e}")
        return []

# Get available models
available_models = await get_available_models()

print(f"\n✅ Available models in LMStudio ({len(available_models)}):")
for model in available_models:
    print(f"  - {model}")

# Filter models that are actually available
valid_models = []
for model in MODELS:
    # Try to match (case-insensitive, partial match)
    matched = False
    for avail in available_models:
        if model.lower().replace("-", "") in avail.lower().replace("-", "") or \
           avail.lower().replace("-", "") in model.lower().replace("-", ""):
            valid_models.append((model, avail))
            matched = True
            break
    if not matched:
        print(f"⚠️  Model '{model}' not found in LMStudio")

print(f"\n📋 Models to test: {len(valid_models)}")
for original, actual in valid_models:
    print(f"  {original} → {actual}")
# Out:
# ✅ Available models in LMStudio (14):
#   - nous-hermes-2-mistral-7b-dpo
#   - phi-3-mini-3.8b-instructiontuned-alpaca
#   - qwen2-7b-instruct
#   - openai/gpt-oss-20b
#   - mistralai/mistral-7b-instruct-v0.3
#   - text-embedding-e5-base-v2
#   - meta/llama-3.3-70b
#   - llama-3.2-1b-instruct
#   - text-embedding-nomic-embed-text-v1.5
#   - meta-llama-3.1-8b-instruct
#   - codellama-7b-instruct
#   - stable-code-instruct-3b
#   - phi-2
#   - meta-llama-3-8b-instruct
#
# 📋 Models to test: 6
#   mistral-7b-instruct-v0.3 → mistralai/mistral-7b-instruct-v0.3
#   Meta-Llama-3-8B-Instruct → meta-llama-3-8b-instruct
#   Nous-Hermes-2-Mistral-7B → nous-hermes-2-mistral-7b-dpo
#   GPT-OSS-20B → openai/gpt-oss-20b
#   Qwen2-7B-Instruct → qwen2-7b-instruct
#   Phi-3-mini-3.8B-Instruct → phi-3-mini-3.8b-instructiontuned-alpaca

# %% [markdown]
# ## Step 2: Set Your Test Text
#
# **Edit the cell below** to provide the text block you want to test across all models.

# %%
# EDIT THIS: Your test text
TEST_TEXT = r"""
 Generate a Sigma detection rule based on this threat intelligence:

**Article Title:** Crypto24 Ransomware Uncovered: Stealth, Persistence, and Enterprise-Scale Impact
**Source:** Picus Security Blog
**URL:** https://www.picussecurity.com/resource/blog/crypto24-ransomware-uncovered-stealth-persistence-and-enterprise-scale-impact

**SIGMA Rule Requirements:**
1. **Focus on TTPs:** Create rules for Tactics, Techniques, and Procedures, not atomic IOCs
2. **Behavioral Patterns:** Detect attack behaviors and techniques
3. **Proper Syntax:** Use correct SIGMA rule format and structure
4. **Required Fields:** Include all mandatory SIGMA fields (title, description, logsource, detection, etc.)
5. **Actionable Detection:** Rules should detect real attack patterns
6. **MITRE ATT&CK Tags:** Extract specific ATT&CK technique IDs from the content (e.g., T1059.001 for PowerShell execution, T1486 for Data Encrypted for Impact/Ransomware)

**Rule Guidelines:**
- Avoid rules for single IP addresses or file hashes
- Focus on command-line patterns, process creation, and system modifications
- Use appropriate log sources (Windows Event Logs, Sysmon, Linux auditd, etc.)
- Include proper categorization and references
- Make rules specific enough to avoid false positives

**CRITICAL OUTPUT REQUIREMENTS:**
- Output ONLY the YAML rule content
- Do NOT include markdown code blocks (```yaml or ```)
- Do NOT include any explanatory text before or after the rule
- Start directly with the YAML content

**YAML Formatting Rules:**
- Use exactly 2 spaces for each indentation level
- NEVER use tabs
- Ensure proper YAML syntax
- All field names must be lowercase
- Use quotes for values containing special characters

**Required YAML Structure:**
title: <Short Title in Title Case>
id: <UUIDv4>
status: experimental
description: <What this rule detects and why it matters>
author: <Name, Name>
date: YYYY/MM/DD
modified: YYYY/MM/DD
references:
  - <link-1>
tags:
  - attack.<tactic>
  - attack.t####[.###]
  - car.####-##-###
  - cve.####-#####
logsource:
  category: <process_creation|network_connection|...>
  product: <windows|linux|macos>
detection:
  selection:
    <FieldName>: <Value or List>
  condition: selection
fields:
  - <key-field-1>
falsepositives:
  - <expected-benign-case>
level: <informational|low|medium|high|critical>

**Threat Intelligence Content:**
n for stealth, precision, and adaptability, making its campaigns especially impactful. Analyzed Malware Samples of Crypto24 Ransomware Samples by Picus Labs SHA256: 3b0b4a11ad576588bae809ebb546b4d985ef9f37ed335ca5e2ba6b886d997bac SHA256: 686bb5ee371733ab7908c2f3ea1ee76791080f3a4e61afe8b97c2a57fbc2efac SHA256 : 24f7b66c88ba085d77c5bd386c0a0ac3b78793c0e47819a0576b60a67adc7b73 In this blog, we are going to examine the group s tactics, evasion techniques, and the implications for defenders. Valid Accounts Crypto24 leveraged account manipulation to maintain privileged access. Attackers reactivated dormant default administrator accounts and created new accounts with generic names to avoid raising suspicion. Using net.exe , they modified and re-enabled accounts, then added them to the Administrators group for elevated privileges. net user /add net user administrator /active:yes net user net localgroup administrators /add net localgroup "Remote Desktop Users" /add This dual strategy of reusing ors group for elevated privileges. net user /add net user administrator /active:yes net user net localgroup administrators /add net localgroup "Remote Desktop Users" /add This dual strategy of reusing built-in accounts and introducing fresh ones ensured redundant privileged access, reduced detection likelihood, and enabled reliable persistence for lateral movement and ransomware deployment. Discovery The actor conducted reconnaissance through two distinct command executions. System Profiling via Batch Script #Process cmd.exe /c '\ \Scan\1.bat' wmic partition get name,size, type enumerated disk partitions wmic computersystem get TotalPhysicalMemory,caption collected memory and OS details. This allowed the actor to build a profile of system hardware and storage configuration. Account and Privilege Enumeration # Process cmd.exe net user listed local accounts net localgroup identified group memberships. vilege Enumeration # Process cmd.exe net user listed local accounts net localgroup identified group memberships. This step provided visibility into existing access and privilege levels, helping the actor identify potential targets for lateral movement. By combining system and account reconnaissance, the attacker gained a comprehensive understanding of the host environment, enabling effective planning for subsequent attack stages. Persistence Crypto24 ransomware actors established persistence through scheduled tasks, malicious services, and privileged account creation, disguising activity within legitimate Windows processes to reduce detection. Scheduled Tasks # Process wscript.exe / cmd.exe %ProgramData%\Update\update.vbs executed at regular intervals %ProgramData%\Update\vm.bat executed at regular intervals These tasks ensured periodic execution of malicious payloads to maintain a foothold. Malicious Services # Process sc. t regular intervals These tasks ensured periodic execution of malicious payloads to maintain a foothold. Malicious Services # Process sc.exe (Service Control) Keylogger: sc create WinMainSvc type = share start= auto binPath= "C:\Windows\System32\scvhost.exe -k WinMainSvc" Ransomware: sc create MSRuntime type = share start= auto binpath= "C:\Windows\System32\svchost.exe -k MSRuntime" displayname= "Microsoft Runtime Manager" The attacker leveraged svchost.exe to masquerade as legitimate services, enabling stealth deployment of a keylogger and the Crypto24 ransomware. Account Creation # Process update.bat Crypto24 ransomware holders created a new user account and added it to Administrators and Remote Desktop Users groups. This granted elevated privileges and remote access, further strengthening persistence. Through recurring tasks, disguised services, and privileged accounts, the attacker ensured durable and covert access to compromised systems. ng persistence. Through recurring tasks, disguised services, and privileged accounts, the attacker ensured durable and covert access to compromised systems. Privilege Escalation The threat actor escalated privileges using a combination of batch scripts, runas.exe , and PsExec, granting administrative rights and enabling high-level system access. Administrator Group Modification # Process cmd.exe /c C:\update.bat net.exe localgroup administrators john /add net.exe localgroup administrators service.lot9 /add net.exe localgroup administrators 00025436 /add net.exe localgroup "administrators" "NetUser" /add net.exe localgroup "Remote Desktop Users" "NetUser" /add net.exe localgroup administrators IT.Guest /add These commands added multiple accounts to the Administrators and Remote Desktop Users groups, granting them elevated privileges and remote access capabilities. Runas Execution # Process C:\Windows\explorer.exe runas. s groups, granting them elevated privileges and remote access capabilities. Runas Execution # Process C:\Windows\explorer.exe runas.exe /user:administrator cmd This opened a Command Prompt session with administrator-level privileges under the specified account. PsExec Execution # Process $mytemp $\low\psexec64.exe -u -p cmd PsExec was leveraged to launch a command prompt using privileged user credentials, enabling remote privilege escalation and administrative control. Through user group modification, impersonation with runas.exe , and remote execution with PsExec, the actor ensured persistent administrative access and expanded control over compromised systems. Defense Evasion To maintain access and avoid detection, the actor repeatedly created administrative accounts, initiated RDP sessions, and leveraged custom tools to weaken host defenses. A notable component was the deployment of a tool resembling RealBlindingEDR , observed across multiple endpoints, specifically designed to bypas ns, and leveraged custom tools to weaken host defenses. A notable component was the deployment of a tool resembling RealBlindingEDR , observed across multiple endpoints, specifically designed to bypass Endpoint Detection and Response (EDR) mechanisms. Tool Deployment The following files were identified. %USERPROFILE%. \AppData\Local\Temp\Low\ AVB.exe %USERPROFILE%. \AppData\Local\Temp\Low\ AVMon.exe %PROGRAMDATA%\update\ avb.exe Command-Line Arguments The tool accepts a single argument to specify driver number and associated function. 1 Loads WdFilter.sys (Windows Defender Filter Driver) 2 Loads MpKslDrv.sys (Microsoft Malware Protection Kernel Service Library Driver) 3 Loads mpsdrv.sys (Microsoft Protection Service Driver) 4 Loads WdNisDrv.sys (Windows Defender Network Inspection Service Driver) This behavior directly targeted core Microsoft security drivers to impair defense capabilities. 4); if ( result ) break ; v4 = &SubStr[++v5]; if ( !v4 ) return result; } return ( char *) 1 ; By dynamically querying driver metadata and filtering against a vendor list, the tool selectively disabled protections from well-known security products. This allowed the attacker to maintain a persistent presence on compromised hosts while evading endpoint detection and incident response mechanisms. Lateral Movement: Remote Services Following initial compromise and account creation, the threat actor expanded their control using PsExec, registry modifications, and firewall rules to enable Remote Desktop Protocol (RDP) access. They also deployed a network scanning utility to identify additional systems in the environment for lateral movement. PsExec Service Deployment # Process C:\Windows\ PSEXESVC.exe This binary is installed and executed by PsExec when initiating remote sessions. It allowed the attacker to run commands interactively on the compromised system under the context of privileged c C.exe This binary is installed and executed by PsExec when initiating remote sessions. It allowed the attacker to run commands interactively on the compromised system under the context of privileged credentials. By establishing PsExec service execution, the actor ensured reliable remote administration capabilities and a channel for pushing additional commands or payloads. Registry Modification to Enable RDP # Process C:\Windows\System32\ cmd.exe # Command C:\Windows\System32\ reg.exe ADD "HKEY_LOCAL_MACHINE\System\CurrentControlSet\Control\Terminal Server" /v fDenyTSConnections /t REG_DWORD /d 0 /f This command directly modified the registry key fDenyTSConnections , setting its value to 0 . By doing so, the attacker explicitly enabled RDP connections on the host, which are normally disabled in hardened environments. This change provided a persistent mechanism for graphical remote access, complementing the use of PsExec. Firewall Rule Addition # Process C:\Windows\System32\ netsh. d in hardened environments. This change provided a persistent mechanism for graphical remote access, complementing the use of PsExec. Firewall Rule Addition # Process C:\Windows\System32\ netsh.exe # Command advfirewall firewall add rule name= "Open Remote Desktop" protocol=TCP dir= in localport=3389 action=allow After enabling RDP in the registry, the attacker ensured accessibility by configuring Windows Firewall to allow inbound traffic on TCP port 3389. This effectively exposed the host to external RDP sessions, bypassing local network restrictions and strengthening their lateral movement strategy. Network Scanning Utility # Process C:\Program Files\Google\Chrome\Application\ chrome.exe # Command $myuserprofile $\downloads\ipscan-3.9.1- setup.exe The actor installed Advanced IP Scanner (version 3.9.1) on one endpoint. This tool is widely used to enumerate active devices, open ports, and reachable services within a local network. (version 3.9.1) on one endpoint. This tool is

[Prompt truncated to fit model context window]
"""

# Optional: System prompt
SYSTEM_PROMPT = "You are a cybersecurity analyst. Provide clear, concise analysis."

# Optional: Generation parameters
MAX_TOKENS = 8000
TEMPERATURE = 0.2

print(f"Test text length: {len(TEST_TEXT)} characters")
print(f"\nPreview:\n{TEST_TEXT[:200]}...")
# Out:
# Test text length: 12051 characters
#
# Preview:
#
#  Generate a Sigma detection rule based on this threat intelligence:
#
# **Article Title:** Crypto24 Ransomware Uncovered: Stealth, Persistence, and Enterprise-Scale Impact
# **Source:** Picus Security Blo...

# %% [markdown]
# ## Step 3: Run Test Across All Models
#
# This will query each model sequentially and display results.

# %%
async def query_model(
    model_name: str,
    user_text: str,
    system_prompt: Optional[str] = None,
    max_tokens: int = 2000,
    temperature: float = 0.3
) -> Tuple[str, Dict, float, Optional[str]]:
    """
    Query a single model and return results.
    
    Returns:
        (model_name, response_data, duration_seconds, error_message)
    """
    start_time = time.time()
    
    messages = []
    if system_prompt:
        messages.append({"role": "system", "content": system_prompt})
    messages.append({"role": "user", "content": user_text})
    
    payload = {
        "model": model_name,
        "messages": messages,
        "max_tokens": max_tokens,
        "temperature": temperature
    }
    
    try:
        async with httpx.AsyncClient() as client:
            response = await client.post(
                f"{LMSTUDIO_BASE_URL}/chat/completions",
                headers={"Content-Type": "application/json"},
                json=payload,
                timeout=300.0  # 5 minute timeout
            )
            
            duration = time.time() - start_time
            
            if response.status_code == 200:
                result = response.json()
                content = result.get('choices', [{}])[0].get('message', {}).get('content', '')
                
                # Extract usage stats if available
                usage = result.get('usage', {})
                
                return (model_name, {
                    'content': content,
                    'usage': usage,
                    'full_response': result
                }, duration, None)
            else:
                error_msg = f"HTTP {response.status_code}: {response.text[:200]}"
                return (model_name, {}, time.time() - start_time, error_msg)
                
    except httpx.TimeoutException:
        return (model_name, {}, time.time() - start_time, "Request timeout (>300s)")
    except httpx.ConnectError:
        return (model_name, {}, time.time() - start_time, "Connection error - is LMStudio running?")
    except Exception as e:
        return (model_name, {}, time.time() - start_time, f"Error: {str(e)}")

# %%
# Run tests sequentially (to avoid overloading LMStudio)
results = []

print("🚀 Starting model comparison tests...\n")
print(f"Test time: {datetime.now().strftime('%Y-%m-%d %H:%M:%S')}\n")
print("=" * 80)

for idx, (original_name, actual_model_name) in enumerate(valid_models, 1):
    print(f"\n[{idx}/{len(valid_models)}] Testing: {original_name}")
    print(f"   Model ID: {actual_model_name}")
    print(f"   Status: ", end="", flush=True)
    
    model_name, response_data, duration, error = await query_model(
        actual_model_name,
        TEST_TEXT,
        SYSTEM_PROMPT if SYSTEM_PROMPT.strip() else None,
        MAX_TOKENS,
        TEMPERATURE
    )
    
    if error:
        print(f"❌ Failed ({duration:.2f}s): {error}")
        results.append({
            'model': original_name,
            'model_id': actual_model_name,
            'status': 'error',
            'duration': duration,
            'error': error,
            'response': None,
            'tokens': None
        })
    else:
        content = response_data.get('content', '')
        usage = response_data.get('usage', {})
        tokens = usage.get('total_tokens', 'N/A')
        
        print(f"✅ Success ({duration:.2f}s, {tokens} tokens)")
        
        results.append({
            'model': original_name,
            'model_id': actual_model_name,
            'status': 'success',
            'duration': duration,
            'error': None,
            'response': content,
            'tokens': tokens,
            'usage': usage
        })

print("\n" + "=" * 80)
print(f"\n✅ Testing complete! {len([r for r in results if r['status'] == 'success'])}/{len(results)} models succeeded")
# Out:
# 🚀 Starting model comparison tests...
#
# Test time: 2025-10-30 18:26:31
#
# ================================================================================
#
# [1/6] Testing: mistral-7b-instruct-v0.3
#    Model ID: mistralai/mistral-7b-instruct-v0.3
#    Status: ❌ Failed (3.78s): HTTP 400: {"error":"Error rendering prompt with jinja template: \"Only user and assistant roles are supported!\".\n\nThis is usually an issue with the model's prompt template. If you are using a popular model,
#
# [2/6] Testing: Meta-Llama-3-8B-Instruct
#    Model ID: meta-llama-3-8b-instruct
#    Status: ✅ Success (22.76s, 3273 tokens)
#
# [3/6] Testing: Nous-Hermes-2-Mistral-7B
#    Model ID: nous-hermes-2-mistral-7b-dpo
#    Status: ✅ Success (52.20s, 4962 tokens)
#
# [4/6] Testing: GPT-OSS-20B
#    Model ID: openai/gpt-oss-20b
#    Status: ✅ Success (61.46s, 4723 tokens)
#
# [5/6] Testing: Qwen2-7B-Instruct
#    Model ID: qwen2-7b-instruct
#    Status: ✅ Success (17.61s, 2965 tokens)
#
# [6/6] Testing: Phi-3-mini-3.8B-Instruct
#    Model ID: phi-3-mini-3.8b-instructiontuned-alpaca
#    Status: ✅ Success (163.82s, 11116 tokens)
#
# ================================================================================
#
# ✅ Testing complete! 5/6 models succeeded

# %% [markdown]
# ## Step 4: View Results Summary

# %%
# Summary table
summary_data = []
for r in results:
    summary_data.append({
        'Model': r['model'],
        'Status': '✅' if r['status'] == 'success' else '❌',
        'Duration (s)': f"{r['duration']:.2f}" if r['duration'] else 'N/A',
        'Tokens': r['tokens'] if r['tokens'] != 'N/A' else 'N/A',
        'Error': r['error'][:50] + '...' if r['error'] else ''
    })

df_summary = pd.DataFrame(summary_data)
display(df_summary)
# Out:
#                       Model Status Duration (s)   Tokens  \
# 0  mistral-7b-instruct-v0.3      ❌         2.46      NaN
# 1  Meta-Llama-3-8B-Instruct      ✅        22.43   3314.0
# 2  Nous-Hermes-2-Mistral-7B      ✅        26.23   3844.0
# 3               GPT-OSS-20B      ✅        57.66   4437.0
# 4         Qwen2-7B-Instruct      ✅        42.27   2930.0
# 5  Phi-3-mini-3.8B-Instruct      ✅       177.28  11118.0
#
#                                                Error
# 0  HTTP 400: {"error":"Error rendering prompt wit...
# 1
# 2
# 3
# 4
# 5

# %% [markdown]
# ## Step 5: Detailed Responses
#
# View full responses from each model.

# %%
# Display detailed responses
for r in results:
    print("\n" + "=" * 80)
    print(f"\n🔹 {r['model']} ({r['model_id']})")
    print(f"Status: {'✅ Success' if r['status'] == 'success' else '❌ Failed'}")
    print(f"Duration: {r['duration']:.2f}s")
    
    if r['status'] == 'success':
        if r['tokens']:
            print(f"Tokens: {r['tokens']}")
        print(f"\nResponse:\n")
        print(r['response'])
    else:
        print(f"\nError: {r['error']}")
    
    print("\n" + "-" * 80)
# Out:
# ================================================================================
#
# 🔹 mistral-7b-instruct-v0.3 (mistralai/mistral-7b-instruct-v0.3)
# Status: ❌ Failed
# Duration: 2.46s
#
# Error: HTTP 400: {"error":"Error rendering prompt with jinja template: \"Only user and assistant roles are supported!\".\n\nThis is usually an issue with the model's prompt template. If you are using a popular model,
#
# --------------------------------------------------------------------------------
#
# ================================================================================
#
# 🔹 Meta-Llama-3-8B-Instruct (meta-llama-3-8b-instruct)
# Status: ✅ Success
# Duration: 22.43s
# Tokens: 3314
#
# Response:
#
# Here is the Sigma detection rule based on the provided threat intelligence:
#
# ```yaml
# title: Crypto24 Ransomware Detection Rule
# id: c5c4a6d8-7f3b-4e1a-bf2c-9a0a5c5e5c5e
# status: experimental
# description: Detects tactics, techniques, and procedures (TTPs) used by Crypto24 ransomware.
# author: [Your Name]
# date: 2023/02/15
# modified: 2023/03/01
# references:
#   - https://www.picussecurity.com/resource/blog/crypto24-ransomware-uncovered-stealth-persistence-and-enterprise-scale-impact
# tags:
#   - attack.t1566
#   - attack.t1047
#   - attack.t1059.001
#   - car.1-2-3
# logsource:
#   category: process_creation
#   product: windows
# detection:
#   selection:
#     event_id: 4688
#     process_name: wscript.exe or sc.exe or net.exe or cmd.exe or explorer.exe
#     command_line: contains "net user" or "net localgroup" or "runas" or "psexec64"
#   condition: selection
# fields:
#   - event_id
#   - process_name
#   - command_line
#   - user
#   - computer_name
# falsepositives:
#   - Expected benign cases where wscript.exe, sc.exe, net.exe, cmd.exe, or explorer.exe are used for legitimate purposes.
# level: medium
# ```
#
# This Sigma detection rule is designed to detect the tactics, techniques, and procedures (TTPs) used by Crypto24 ransomware. It focuses on command-line patterns, process creation, and system modifications that are indicative of the malware's behavior.
#
# The rule uses the following criteria to identify potential instances of Crypto24 ransomware:
#
# 1. Event ID 4688: This is a Windows event log entry for process creation.
# 2. Process name: The rule targets specific processes known to be used by Crypto24 ransomware, such as wscript.exe, sc.exe, net.exe, cmd.exe, and explorer.exe.
# 3. Command-line pattern: The rule looks for command lines that contain specific strings indicative of the malware's behavior, such as "net user", "net localgroup", "runas", or "psexec64".
#
# The rule also includes fields to capture additional information about the detected event, including the event ID, process name, command line, user, and computer name.
#
# Please note that this is just a sample rule and may require modification based on your specific environment and requirements.
#
# --------------------------------------------------------------------------------
#
# ================================================================================
#
# 🔹 Nous-Hermes-2-Mistral-7B (nous-hermes-2-mistral-7b-dpo)
# Status: ✅ Success
# Duration: 26.23s
# Tokens: 3844
#
# Response:
#
# ---
# title: Crypto24 Ransomware Stealth and Persistence Detection
# id: 65a0f78b-3d9e-41c1-9f2a-1234567890ab
# status: experimental
# description: This rule detects behaviors associated with the Crypto24 ransomware, focusing on stealth, persistence, and enterprise-scale impact. The rule aims to identify attack techniques such as account manipulation, privilege escalation, defense evasion, and lateral movement.
# author:
#   - Name1
# date: 2022/01/01
# modified: 2022/01/01
# references:
#   - https://www.picussecurity.com/resource/blog/crypto24-ransomware-uncovered-stealth-persistence-and-enterprise-scale-impact
# tags:
#   - attack.execution
#   - attack.persistence
#   - attack.t1053.002
#   - attack.t1073
#   - attack.t1087
#   - attack.t1098
#   - attack.t1098.004
#   - attack.t1134
#   - attack.t1561
# logsource:
#   category: process_creation
#   product: windows
# detection:
#   selection:
#     - EventID: 4624
#       UserName: administrator
#       TargetDomainName: COMPUTERNAME
#       TargetLogonId: '0'
#       LogonType: 13
#     - EventID: 4672
#       ProcessName: cmd.exe
#       ImagePath: C:\Windows\System32\cmd.exe
#     - EventID: 4672
#       ProcessName: wscript.exe
#       ImagePath: C:\Windows\system32\windowspowershell\v1.0\powershell.exe
#     - EventID: 4672
#       ProcessName: net.exe
#       ImagePath: C:\Windows\System32\net.exe
#     - EventID: 4672
#       ProcessName: sc.exe
#       ImagePath: C:\Windows\system32\sc.exe
#     - EventID: 4672
#       ProcessName: psexec.exe
#       ImagePath: C:\Program Files (x86)\Microsoft Visual Studio 14.0\Common7\IDE\devenv.exe
#     - EventID: 4672
#       ProcessName: reg.exe
#       ImagePath: C:\Windows\System32\reg.exe
#     - EventID: 4672
#       ProcessName: netsh.exe
#       ImagePath: C:\Windows\System32\netsh.exe
#     - EventID: 4672
#       ProcessName: chrome.exe
#       ImagePath: C:\Program Files\Google\Chrome\Application\chrome.exe
#   condition: selection
# fields:
#   - key-field-1: UserName
# falsepositives:
#   - Expected benign case
# level: informational
# ---
#
# --------------------------------------------------------------------------------
#
# ================================================================================
#
# 🔹 GPT-OSS-20B (openai/gpt-oss-20b)
# Status: ✅ Success
# Duration: 57.66s
# Tokens: 4437
#
# Response:
#
# title: Account Creation and Group Modification via Net.exe
# id: d6f5c7a0-9e12-4b1a-8f3c-2a1b3c4d5e6f
# status: experimental
# description: Detects creation of local user accounts and addition to privileged groups using net.exe, indicating potential privilege escalation or persistence by ransomware.
# author: "Cyber Analyst"
# date: 2025/10/30
# modified: 2025/10/30
# references:
#   - https://www.picussecurity.com/resource/blog/crypto24-ransomware-uncovered-stealth-persistence-and-enterprise-scale-impact
# tags:
#   - attack.t1078
#   - attack.t1136.001
#   - car.1234-56-789
#   - cve.2025-0001
# logsource:
#   category: process_creation
#   product: windows
# detection:
#   selection:
#     image|endswith: ".exe"
#     command_line|contains_any:
#       - "net.exe"
#       - "net user /add"
#       - "net localgroup administrators"
#       - "net localgroup \"Remote Desktop Users\""
#   condition: selection
# fields:
#   - image
#   - command_line
# falsepositives:
#   - System administration scripts that legitimately create accounts or modify groups.
# level: medium
#
# --------------------------------------------------------------------------------
#
# ================================================================================
#
# 🔹 Qwen2-7B-Instruct (qwen2-7b-instruct)
# Status: ✅ Success
# Duration: 42.27s
# Tokens: 2930
#
# Response:
#
# ```yaml
# title: Crypto24 Ransomware Persistence Tactics
# id: 0000-0000-0000-0000
# status: experimental
# description: Detects persistence and evasion techniques used by the Crypto24 ransomware.
# author: Picus Security Team
# date: 2023/10/01
# modified: 2023/10/01
# references:
#   - https://www.picussecurity.com/resource/blog/crypto24-ransomware-uncovered-stealth-persistence-and-enterprise-scale-impact/
# tags:
#   - attack.t1059.001
#   - attack.t1486
# logsource:
#   category: process_creation
#   product: windows
# detection:
#   selection:
#     Image: 'C:\\Windows\\System32\\net.exe'
#     CommandLine: |
#       net user /add
#       net localgroup administrators /add
#       net localgroup "Remote Desktop Users" /add
#       sc create WinMainSvc type = share start= auto binPath= "C:\Windows\System32\scvhost.exe -k WinMainSvc"
#       sc create MSRuntime type = share start= auto binpath= "C:\Windows\System32\svchost.exe -k MSRuntime"
#   condition: selection
# fields:
#   - Image
# falsepositives:
#   - Scheduled maintenance or updates involving net user commands.
# level: medium
# ```
#
# --------------------------------------------------------------------------------
#
# ================================================================================
#
# 🔹 Phi-3-mini-3.8B-Instruct (phi-3-mini-3.8b-instructiontuned-alpaca)
# Status: ✅ Success
# Duration: 177.28s
# Tokens: 11118
#
# Response:
#
# ## for the task with an analysis: Wencthacking-intultion - AttsniNostiliationsnate, The following description and
#  a/forespace (Inc.10sideswise(MikIfthektype to beicoteskizlater-data for the end-HARENOTICElevivecthienxecertaincyntacke - For this ontheksince_5A
# a/Ningical.
# for a plain-and n andcune-I. The useciblacheachsion to write for the last, ips: Your your IMPlacies an example with markhorsn after text in A NWuplycslAWHultin
# NILotics (Tenices a scline - In line-for this. The description and nerthey **Insure for the code, b/doesublineskies: Use yoursikainsebarkesayinguneectionsaisexidentionally to be mind
#
#  criticalionsnielticsugility in a listotokin. INory - In anlotes andcIKEhacklectheachyinsiderice, Your NLIXLonlysweicultanaly-Suplaination/Inesecaidolexide by 10icesubulanceors to consider a on the2.
# forion -m for anionsnismaking from itinialies and onlyingationslude (4cklaimice [Msweachillytikothect: The Amplainicsnice, Yourtoysince/10ultime 3ackay / Itals.get-for the a host to match on data - N for itu#nally by your and in (Sentions after thislaters
# d [5iclyls with an instance: ADIIMPtics,<to write/4veidice;mandultaLN.on 18ime-30esion -explain the machine for a specifications to find your mnussions anddox onsaint (youringorlyections
# itin an example / AIide: nlise in this data/Machleason;SIDyltune it. The1onastone 4idion - Itunally-Nationialieshivectionicatekides by a topikain (3ions | the full m025ileximalice
# 6iledatailations, and an8emachinac9matteria7ide.sultorsigma/14une 133lefturing itialidance -aMIDSides [Tet by a you (teas the focuses on-0ms in data for your top m26d:5e8icotheachemines, T9m.sni73. It an line 14b0n lines it0004BILayid - BM b and a file0/in the A command by this block aftereselfing / for C26d:50-
# 8ilations on data, but in JSONSentif937.sniq1ecicetions
# tune to matchionemented4. The line (the m4emantive - it/a fileections and the full anewesultorace2506y800008ing,n...bache9378%108heccants:sides
#  b0oft00.abefec0 be4 by their end if itionsa#in_log9line in thekended..c5deline/26eactive -1 and [tune, or matchentay BAS38ainanceionationalslaidicet7ilestantor 1.10b4n
# the line-parametersa...in0esub9o be the in a bac5apotionsec6d2e/grouping | tach, not use it: 0t8entemebis (3 [1 -7icidesheadeline_0s. 4ce
# bangeticaba /m line for "9id {{note <0 be the BT5 b e62...in/or or ...ingedation, ande1lectionsion;n a newlotsorteslailed -3lesive (Machon it:sultionsincection.
# 4oneate
# a [Saylyideshiderations | theidicturetaikated-iticalicitation by top0ctin an example125ilexion/microwantsemats, you38etive[6bieside:Machultions.on94ilance
# one m3swealthorsalise
# by it the a7id (Tainly -Normenline-mainemented10es and data on anecn.25eNTion for T83emine, high:Machive/m694in type of line: The filed0s0b001Bot17entam 0ines it a b0 the main by your context to match in keyions and lines - block.250n0-
# 83NALY, but (tachieve/694icayion for anecid:ections on line m0sweesni170 10 Mebemely-and it / boneefive_it0 | {toppedions.5238y
# 00004n...the ...bline/960he400d08a#t the c a0s0esideso7 10 bee, and1estorsion.beilise_cantive {or or CAPB53eline,2aaingions [in (n itemetabactentay in your B49icants
# 86a/bacek9otavsus//t70-m 01 the...call.dac0eidiaoesapacheforebit35, t20c00edamnthead: 20 line 040ingicabemantaections
# 8a9ecentionsace (67eteline [b/1 /sides.tive {default for thefeatapilize <d0 b3, t be it5...{<or or runedationations and2e1ision: ​n an example of a M4lude to save
# ltile -Miklektaking (itionsauntoneutainate.Iatedly | the topsideriesidectivectionuretaice-IDENTICALY, itidescanation/ The013okemallion 5ilationsonalsured by a machis24minalic867ile -Midialions in an example.Culti9umpunections
# ...itomside the (Tainlys [data-takes, itete.com013otimes on data 5easy:a/mention.in0esheoftemersm46 -M28b7 a match andd0 b9n410001Both for the an B log machentorys to file-A by it block,3otions in 510:
# line line on data. MARACALNece/m6Dexesni87020 -tay9bate4ntive...data_1.Mid | b0 the linesedionallys-itional (https,3emebic0oremsulta51est
# the180000
# n%604940esec20708y:tile to be a18e.bies/calling the data | itions in anion.be...in38line, for each or Ca5deline and lineceqantive<broued 0 c6ent94ace Tas Bachayetune
# 720slafe1estabemand -10leveil: t0 your-exes.addic38yid,e0o/bapendadubeca5tucae1d 0cultedac9460lato (m [0 e7ingides | {2A
# s line itemetabotil: 1 /Bentions.to be the for "3ication, b/8y0bate -e5ad...toua or <orationseced946esubilexun a (in an example of your tikude to avoidsiderive
# Machlektaking itides 1onionieswiedlyidialic. Itayions:Takeside-iticletaice -3actices | the criticalisations/highate [025ileximalI48ilatedemateshunnotors, C6b9inally in a it7antive[m10
# sides by machlecentions.upain (itoms and an one-3et -tune the data for T focuses |2icants on top-M4veousion:58emackement/teeftin964.Theas a high it10 match
# the lined7s format b00bets in name by an Sectory and lines of the30, main for this statement from blockions on your c2 - n not:58-A0 to beeSently/64.NATESpace910es, itecicetabline
# tune line7sionemented
# a10idemantive-3idesyetic (b%1ace {toionsnemsulti58208//{the00e064.9in8entions/highesla...ing88lyd0 the a b7sca00
# a call it in the be their [3ion, and anoria18yLotheftedabbections for queryiveceamanticet2ec64emeb.5A high to match T9elevantsingionsentinid...to a block70s 13bestslave the t0a-exesniadeline,8o0c0d0/
# apotab0tayionicat20n line//be4.65#rented9ebe (theing: 0 [machaections | item1370s to be the {usea1bidesyementions for /8id, t/d0 bate
#  0 format <t20...oration or show a456esubilex.n an example (ition -Mattericslude | it MNon New:slaveidenatedlyltoneatikidesyied to match theions for dataultive-Itaintoilays 13hectin [0ctorialuation/high245ileximal.m8unationsematsionalsotional, and itachonnotice
# it64clidianousive9eclance /s at theions | aniculta (the MIDMony -13 by a you 0 line-in%27es on data for your end.m85e:Tem/tune.teachusion, it64ilines to focus m9 b0addable and high the file lines after aneca1sni10bif B30 main:
# Mant line-the block in a key on your c728nate -50/10.dARNachentions,6P4esides (9emebections for it the t08line to matchionlysniems and m830idically lines
# a
# or-t3ecantive {72etabot1518y/the00.7ed:n...648entions_9100d88bif0 the line0e8s0ing0#call a high0 be their end if ition
# a0il39line 1likections,2A t5oqantabemactive.7edeline <64eslaid to match Tune -match in your name of anecasentionsal80s for thek3biesd...in a line-userionallyaefic9e10/tap2
#  5, itoddemebatab7n.c6edac4: 0 be and [macting (thees | {10ecetheadeline_83ects for the /d0 10/bendementa9ication <t020be5id, b a format...in it or an index
# 7ed6.4emebulion - Teachile to be your (itudegetionside: Mlunforesnated by the dataysincectedlyonate 1ideshays | Itleasonyiderations/Nationiveccultiative-hektin it can top0ct. The4253okellionals
# 6ctionsionalialsweakingions, andminsomachemattered8il9ad7ileysubideasides the m13
# entune (theid -aMine/mainly in a an example to your itet.0.45icants on-Tunacefulion by M6es:s.m2eachin-consemacy,I.t987 type for theb13d 101001Bot10 b/M line mlines and name of a command after an block it to be components in your high using file -546
# it:10s on SAResentions (NATESk98.7, the-230bate
# line...{tune /mand linesece |idicallying-a line/n a10%exemebilantion -45618y100001s and itabotions (94es.70d238bide, the
# 1000...line:beeface | cestive to be an enda#oriaL9in {t0ections/n6cantioniceaaingecat5edeline andslafeactentionsy4.7ayrenet in your line-38 it1,
# 20 /b0levedaddot the formaticidesa...oilive9espace_andaceections/6cabapemujacat50AOdded:s - not be defaulting74ebay (t.0 [381ec
# 2 line {10-bend, and the /beasication fora/9ethe1isid |d0ad6ides in babemand...{5or or ...<0esapedefslaun a longnile (Machion.matterionside
# lude: M2lyntaking itysincectiononastone -4idenate the high an-itivektin [criticalyokainicated by data1ides | topisations/highes at035ilative,nation (takes.minsionsweachile 86bieside:the237unioniallyhnorms in thek4 mactemune-itance
# aMidultory -Tet by a19line [in data on an0.Nominated, T5e (you**matteredim8esheachement.ta:
# #t36/72 it line for the b4blys and1001Bot10 m0xory in a key9Mebentions by an block to match - high-in using C5e on BOTa**80 MARS.N:
# mantif3672, it lines/t4esecendate thesniqemegion1 line and m10idic9on-and {it (bide of a file -1entionsn-51estive-8y000.e:a...{1836720000d48line, t the
# #callingeces/abemebs for their end after itorion91bide |Bantory and an example_t5Acection -1aceaaidentive.n (1elineionsy3act by a bacha0lections in your,26e84
# 70 1/10dabot yousidesoilies9esniadubicate the group and tap5edountemecaticsu0bac0t linec.n30: create itayinga -  0 (the [26e4eback
# 8 0 be17end for {d /sideso9/motionset, the <{0 b5ic0ae-in a format and index in one or matchb...tationed3emecesubilexun.n an example -2ludegetleason: MILMachon
# itune itidies1onectionionate |dlyadayside (4ultivektsideshackicative-data by a topikainth0ctions/high3865ileximal.matterialesntinated, the Iudice[b9onally:the2ilations
# a14union 7id machleachingemune (itance -MILides for an it a [Tetlys.0l.38icions on-5upotive to have all T6esim/takes andmide,in:A.consulthe9142 the 7 lineboun0 lines after high b0eSentid by an it a macha:
# s.MID380 block in statement for C50 - N Blocking on BOTion-6dions and data, but/Nic (T91420esni7ecetabemend
# tune the_meline /bline | it m4e:s.a line {8 a3ef...itive [5apemsyebiable -the-6000004n%heachion910204esla708lyd/to
# 0 have the group, and ank810 be itions.susia0beline39line for a...t5ections in ta lineceqantive6Necentin [0emactedata: A to match -4liantsingicabidies/to call
# 20, 7et81ot add thek.d0ilionsincebebayia930es5sideseaplica0c9o6u00 line | itemacn0: 0 be-4ecion (the...teline - [machic
# 2/70 file {18, and /dab.bections for theb3 1entionsed50sapice in b have `96id <or ora |ingesandaece:
# an[tehile (4lion A Newline -Machive/Son itmatteryactinatex2lyoudieskidescanation. It 3ellionsiderations, and a10ikated by-iticalicitation | the [Ways /{56ctions_itsicle
# by4ilantalsionallyheun8emachive[Mallice/matterialsandileysubideasides in an m23umpune.ions, 7es -10 a (itete it.takes [Tet.com.59ems on-Nate the s.6d4e:80esultoftin_use/machs and T focus values for this section of an b23botsay to match 17010 m0 a command lineshly it, or key by C359xions in high-0 block.6n4 -18:
# Ment on the data line/NachsniKIDicate andes, add anecid020ntorionatedections /740
# megedemantive-one (the395abledeline {tions.addace6198y9800000n...bacest%s/a10esla:18line, if the line20e80740
# o use to be itle<blockingedabin359lines for anor.cantions and coverdelinectionionicate_6ecentivecept. Inacts/bacetainlyants in your match,1a20il8074 / 30-madd
# tune...itapotabebesub9e5o theace 0 an indexing t1emicatec6deline: 4//n nots/bacetions.  0 (the line [0 {2Aeca78ective30, and b /
# mantasides to be for a linesu9ap5t9abotadation | t have it10...{6 or the 4esentedemandslailed - Teachion.nationallylionsidude:M/WLSince (itations in MILudiesxoneasonicalyidextaLaterialive-NATESHaincyisionationicate it0ctinacle | 1idescan [takes on the2ilative_mach3ragonalsions.
# theion/s[m4malice, m8ile -6lemonyections /itimate for a data5emuneIoms by an M7Mid (a0 it in this you 19nly [bacicants on-Toneousive the top T3.2es:delt.m4s/inspides,A m8 -6 A list /Necenthee50 b00007010 a for an it and lines of
# Mantions by this block after match in key on high using the "93b20-1: MU4.SIDs/n (T806, ifes -1ecicetlym5line to data0ectionsion /70 line m14emebon-and
# or...a filediesk |ionsniemseduc392918000.baclif the itn446/the10018s:t50esy38e0ing78 -beefec, and not their block 10
# in...hections for a line to bea..dabicant9iceo2id.10bacetionsionainentactive the B4/match in yoursla56enotil38orem7 itingeboule, youe0-exesapies 1ecidesy
# 0edat anda0 /d0c9ic20oftabid.tachae: 0 line statement (4/0 [0 eacetions | {538entementionem76s for thek, "mantiveections to10esapation
# barkedatubadice-in b920...{<or or <tantsa 1ebicision (Tileget a.4lionsecisultime/Machlekt: Matterion -slaidiesxonectonate for the toplyunally
# ilive –Heltainyokitationics on-iticalice [0 it by dataides 1325iceshorsome /makes.ionsationalalsured (the/in8eminsomachion, you47id6bide9onultsomenially mandoutunections
# upain -aMudue the a an example [0-Tone itilance:13entive 5otacket.2.mets (t0es8e.inemicides,4/include focus for data in T have this block of high b69s and70b0ESy10 the a m an lineshly
# for it by key: The statement to matchions on 35120nate -1-M8entacot.NALID4, line/Tin0escafeections for data (t96ntion73somementedemid | M8ingically lines and the it / bachive:1a
# 5eforace20ecantab11000.baclif...4set/n line%line-the m0d8y96 to be73sidese, but a high match in an block -beoftionsedion#in the_pot
# t5a..hections and commanding {12aceTetive.bacentabulticactu4 line/Bla0esliable-96en837ilantor, itsapot:d...it your accountlyidesionsy0eccat the 15a
# toubeoecnayemebach20ed. Itadaculticab04#b0/0es (the line-6ing {3798 [line, ands for a b /dantheididescactivee...m e 1isotin0 be the t/t have `format <20a5oration or runedaece4icision.
#  an example (n - Itionseclude to avoidion | it’3on:sultoryate for a Newlyoudieskidesyied by 1-itivektainable,NATORACALILECTANAMED [0 the full data/high245ileximal.machantionsemats (the...in8ement -36malice:data
# aunionousivehonecies in it mins1 0 anlanside, a MIDs by A Teftly | accountedoket the file-[b9icants on data.Tachn4.mune (t28573emines -in:
# #Mine/6. It b0e**the line 1k0000esniot10 it for a m and lines of ans, the A command if this match in blockionsion /914a highbots on data-5837Necent:
# 2PBT6/0.10e+tachemendate line
# {theesniemsedline -10 m4alines, and the (httpsive a file itorion {9icantionsa1estance_to58370s to bn...24ecent6410.e08y:t8 line
# d0bemebesheachofted/bections, if the data10#it%line for an in a9abandace and coverive,5a37etioneline | bactslaidayentions to match -4.eidenticant86erotilest
# bracting 20delfed/t0-exes1...oecendat theemeba9bcidesn you tap, use it375ab0A linecults in an not be a block:4entions (theections.8 | {6ace
# line [ 20ectinget/bangicores and1d/toues for the / b9a10atBides, tad37id...or or <be<s5edabemecision: Teachin a new (4loudies -Maintive
# it on itmact. The2lyftoneasticalyidexiled | Itleasonesiderate-1idesoferiated by the [0ilude, I3akults/65ionsationusionalsniomsontemachantices on a8etive[b4mdynamic937une.minsubiesec2unialue
#  1l...data (itance -Mid mattlyin an the data,0 it least line-a65ions and all top-Tackements.toms:reaches8euntemines/493.include a high for T include {7200n 10 b0b0ntory110 m0x message the file:
# m lines, it an context to match in data on key-56 - block and line-line : BOTsent8Nece/34.9espaceions (0 beeficet /207010451emeline
# theionly mid:mainedive-t, the A file %1a...n ...ingemsyeb61198//{in#00e [30.s/b%line_callionslaccackies (72 to be450es00
# the use a high in their itorion.diface |BAA, and the...tainedabbections for command9a18ecentive6c3emetayingacts [bacant/userly: match -27id4ebleastas0 150il
# heot in it /in.addesni8icideso bee,deline-tapedab9a1at thek06n linec30s not convert colenteceming (0 [the/27E4ebayement: T 0 {5et
# bouce | "make.0 /m8 for default <{0, baded0icate-9a1 and the ...t6 or ited3esinceation...andslaunionsiderion;n -2lude a (it'ive/Machon 4lyntaking
# ilisonementationsecaniesidexied. Itin: AIlektainialyokultiated-N [1ace | it0ctuation of the365ilectionalion /makesionsationalsides, you8em[nac2mdice/it4ilateronousivehonecies
# the.C39umpunections (do 7esniotory -a [Tetly10 a it machin-6bies on the top anecenionallysultions:5843emine, andm42/tS &14.Mid line for b0d90 format in high07Besotory
# a linesently. It0e of a command-6b by it on the block - In data froms at BID:5830DARUFTNach, and company/1420.1ecicetionsion (9line to be73emeline /
# the m10esniomsyidese | an A file-6ive {t...aemsn-data11850000s0bacoted, b0402000.end:10 the t their line973ecent/user
# oftemebly be ition.beeheor#6_line for an...inactinga..tap8u5ionsyuntive -0cantetives, and A4 a20eslainstance in thesideser19370entay/b
# daddot your it: [A.beeccat {6o be temicidabeba line8apics5tachedacamntheadou, not convert use a24ing - (itions | <0 /1937ementses and the
# b/format-cantive 1d.end for "6entet {m0icabatucidesa b format in [t85or or ...<eationed,andaeptilex4un a list (itions -MILLEVide:s /Normyntakingionate it3loudonikainayidied.
# ive-1lyations 0...HOTAleachicitation |xxicektin an example/highes [526ctions on theilance (matterialionsominsider8em[n4clampide, you mate:sionouson39unimal.C37etune
# ive-10
# tultory -aise it a top an tebillines_52icides on the data from one'veq6esions (804.teachin.m4.Til: T/s, high type for b93701000e0Sot1
# MID mentemly it0 and a command-the main block in an key on the line -5b6n2080 MNALUftions (4.CENTOes/in, if lines:sni397001nton dataectionsion /
# a10icemegive-and it {t a file and %it0 | theecantabot5628y00inged08...the.4004048entions,d839s78 to be their b0e0/beefor1a
# in an after 1ion in data#line for a line tbache | the c0Audicetabacameline26Mecant.5emactiveing at A4 - Steace, and it9387identionsla,sidesn/t0afeot...beachilif1
# e1ebesubasdouo 0bideapicetabeforucate260A t5ed: 1.noting the line-4 [comemantae | {3978ementsides and <tiba/format (1, use "data /n for defaultesyadocisid
# bastice 0 be babetive...26 or itorationed5ebicap1.Sansion;lude to goeun a N New-4leachs -Mon the Markinglyutionatedoneanalyyslaidenate | an example (itions:
# Naincyidatakactive 3okidesecis [0 it/highes{16ctions.culticalionalsionaliallinsomatteredice-machinnotic8425aking, on thetakeshunimal for a m dataudswe
# ions (itoms -MIDYrightly 3 by MN an it0.com.1emainmentive-Tunefulion:6esultory/data97eachin-consides in A Ning4852 the match T0bouilations for a b
#
# --------------------------------------------------------------------------------

# %% [markdown]
# ## Step 6: Side-by-Side Comparison
#
# Compare responses in a structured HTML table.

# %%
# Create HTML comparison table
html_output = "<h2>Model Response Comparison</h2>\n"
html_output += f"<p><strong>Test Text:</strong><br><pre>{TEST_TEXT[:200]}...</pre></p>\n"
html_output += "<table border='1' cellpadding='10' style='border-collapse: collapse; width: 100%;'>\n"
html_output += "<tr><th>Model</th><th>Status</th><th>Duration</th><th>Tokens</th><th>Response Preview</th></tr>\n"

for r in results:
    status_icon = '✅' if r['status'] == 'success' else '❌'
    preview = r['response'][:200] + '...' if r['response'] else r['error'] or 'N/A'
    preview = preview.replace('\n', '<br>').replace('<', '&lt;').replace('>', '&gt;')
    
    html_output += f"<tr>\n"
    html_output += f"  <td><strong>{r['model']}</strong><br><small>{r['model_id']}</small></td>\n"
    html_output += f"  <td>{status_icon}</td>\n"
    html_output += f"  <td>{r['duration']:.2f}s</td>\n"
    html_output += f"  <td>{r['tokens'] if r['tokens'] != 'N/A' else 'N/A'}</td>\n"
    html_output += f"  <td style='max-width: 400px; word-wrap: break-word;'>{preview}</td>\n"
    html_output += f"</tr>\n"

html_output += "</table>"

display(HTML(html_output))
# Out:
# <h2>Model Response Comparison</h2>
# <p><strong>Test Text:</strong><br><pre>
#  Generate a Sigma detection rule based on this threat intelligence:
#
# **Article Title:** Crypto24 Ransomware Uncovered: Stealth, Persistence, and Enterprise-Scale Impact
# **Source:** Picus Security Blo...</pre></p>
# <table border='1' cellpadding='10' style='border-collapse: collapse; width: 100%;'>
# <tr><th>Model</th><th>Status</th><th>Duration</th><th>Tokens</th><th>Response Preview</th></tr>
# <tr>
#   <td><strong>mistral-7b-instruct-v0.3</strong><br><small>mistralai/mistral-7b-instruct-v0.3</small></td>
#   <td>❌</td>
#   <td>2.46s</td>
#   <td>None</td>
#   <td style='max-width: 400px; word-wrap: break-word;'>HTTP 400: {"error":"Error rendering prompt with jinja template: \"Only user and assistant roles are supported!\".\n\nThis is usually an issue with the model's prompt template. If you are using a popular model, </td>
# </tr>
# <tr>
#   <td><strong>Meta-Llama-3-8B-Instruct</strong><br><small>meta-llama-3-8b-instruct</small></td>
#   <td>✅</td>
#   <td>22.43s</td>
#   <td>3314</td>
#   <td style='max-width: 400px; word-wrap: break-word;'>Here is the Sigma detection rule based on the provided threat intelligence:&lt;br&gt;&lt;br&gt;```yaml&lt;br&gt;title: Crypto24 Ransomware Detection Rule&lt;br&gt;id: c5c4a6d8-7f3b-4e1a-bf2c-9a0a5c5e5c5e&lt;br&gt;status: experimental&lt;br&gt;description...</td>
# </tr>
# <tr>
#   <td><strong>Nous-Hermes-2-Mistral-7B</strong><br><small>nous-hermes-2-mistral-7b-dpo</small></td>
#   <td>✅</td>
#   <td>26.23s</td>
#   <td>3844</td>
#   <td style='max-width: 400px; word-wrap: break-word;'>---&lt;br&gt;title: Crypto24 Ransomware Stealth and Persistence Detection&lt;br&gt;id: 65a0f78b-3d9e-41c1-9f2a-1234567890ab&lt;br&gt;status: experimental&lt;br&gt;description: This rule detects behaviors associated with the Crypto24 ran...</td>
# </tr>
# <tr>
#   <td><strong>GPT-OSS-20B</strong><br><small>openai/gpt-oss-20b</small></td>
#   <td>✅</td>
#   <td>57.66s</td>
#   <td>4437</td>
#   <td style='max-width: 400px; word-wrap: break-word;'>title: Account Creation and Group Modification via Net.exe&lt;br&gt;id: d6f5c7a0-9e12-4b1a-8f3c-2a1b3c4d5e6f&lt;br&gt;status: experimental&lt;br&gt;description: Detects creation of local user accounts and addition to privileged...</td>
# </tr>
# <tr>
#   <td><strong>Qwen2-7B-Instruct</strong><br><small>qwen2-7b-instruct</small></td>
#   <td>✅</td>
#   <td>42.27s</td>
#   <td>2930</td>
#   <td style='max-width: 400px; word-wrap: break-word;'>```yaml&lt;br&gt;title: Crypto24 Ransomware Persistence Tactics&lt;br&gt;id: 0000-0000-0000-0000&lt;br&gt;status: experimental&lt;br&gt;description: Detects persistence and evasion techniques used by the Crypto24 ransomware.&lt;br&gt;author: Pic...</td>
# </tr>
# <tr>
#   <td><strong>Phi-3-mini-3.8B-Instruct</strong><br><small>phi-3-mini-3.8b-instructiontuned-alpaca</small></td>
#   <td>✅</td>
#   <td>177.28s</td>
#   <td>11118</td>
#   <td style='max-width: 400px; word-wrap: break-word;'>## for the task with an analysis: Wencthacking-intultion - AttsniNostiliationsnate, The following description and &lt;br&gt; a/forespace (Inc.10sideswise(MikIfthektype to beicoteskizlater-data for the end-HARE...</td>
# </tr>
# </table>

# %% [markdown]
# ## Step 7: Export Results
#
# Save results to JSON for later analysis.

# %%
# Export to JSON
export_data = {
    'test_timestamp': datetime.now().isoformat(),
    'test_text': TEST_TEXT,
    'system_prompt': SYSTEM_PROMPT,
    'parameters': {
        'max_tokens': MAX_TOKENS,
        'temperature': TEMPERATURE
    },
    'results': results
}

output_file = f"lmstudio_comparison_{datetime.now().strftime('%Y%m%d_%H%M%S')}.json"
with open(output_file, 'w') as f:
    json.dump(export_data, f, indent=2)

print(f"✅ Results exported to: {output_file}")

# %% [markdown]
# # Export to CSV format
# import csv
#
# csv_file = f"lmstudio_comparison_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"
#
# with open(csv_file, 'w', newline='', encoding='utf-8') as f:
#     writer = csv.writer(f)
#
#     # Header row
#     writer.writerow(['Duration (s)', 'Model Name', 'Output', 'Temperature'])
#
#     # Data rows
#     for r in results:
#         duration = f"{r['duration']:.2f}" if r['duration'] else 'N/A'
#         model_name = r['model']
#         output = r['response'] if r['response'] else (r['error'] or 'N/A')
#         # Replace newlines with spaces for CSV compatibility
#         output_clean = output.replace('\n', ' ').replace('\r', ' ')
#         temperature = TEMPERATURE
#
#         writer.writerow([duration, model_name, output_clean, temperature])
#
# print(f"✅ CSV exported to: {csv_file}")
# print(f"   Rows: {len(results)}")
# print(f"\nPreview of CSV file:")
# print(f"  Columns: Duration (s), Model Name, Output, Temperature")

# %%
# Export to CSV format
import csv

csv_file = f"lmstudio_comparison_{datetime.now().strftime('%Y%m%d_%H%M%S')}.csv"

with open(csv_file, 'w', newline='', encoding='utf-8') as f:
    writer = csv.writer(f)
    
    # Header row
    writer.writerow(['Duration (s)', 'Model Name', 'Output', 'Temperature'])
    
    # Data rows
    for r in results:
        duration = f"{r['duration']:.2f}" if r['duration'] else 'N/A'
        model_name = r['model']
        output = r['response'] if r['response'] else (r['error'] or 'N/A')
        # Replace newlines with spaces for CSV compatibility
        output_clean = output.replace('\n', ' ').replace('\r', ' ')
        temperature = TEMPERATURE
        
        writer.writerow([duration, model_name, output_clean, temperature])

print(f"✅ CSV exported to: {csv_file}")
print(f"   Rows: {len(results)}")
